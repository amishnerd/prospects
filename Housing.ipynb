# %%
import pandas as pd

# %%
# The path to our CSV file
file = "SFRCity.csv"

# Read our Kickstarter data into pandas

df = pd.read_csv((file), sep=',', encoding='latin-1')
df.head()
# Out:
#    RegionID   RegionName State                             Metro  \
# 0      6181     New York    NY       New York-Newark-Jersey City
# 1     12447  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 2     39051      Houston    TX  Houston-The Woodlands-Sugar Land
# 3     17426      Chicago    IL          Chicago-Naperville-Elgin
# 4      6915  San Antonio    TX         San Antonio-New Braunfels
#
#            CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  ...  \
# 0       Queens County         1  206218.0  205985.0  205806.0  205741.0  ...
# 1  Los Angeles County         2  189955.0  190085.0  190270.0  190523.0  ...
# 2       Harris County         3   95290.0   95449.0   95556.0   95605.0  ...
# 3         Cook County         4  123691.0  123363.0  123464.0  123339.0  ...
# 4        Bexar County         5   93324.0   93262.0   93249.0   93252.0  ...
#
#    2019-04  2019-05  2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  \
# ...

# %%
rdf = df.loc[:, ["RegionName", "State", "Metro",
                                    "2020-01"]]

rdf.to_csv("Housing.csv", index=False, header=True)
